# %%
import random
import shutil
import time
import warnings
from datetime import timedelta
import datetime
import os
import boto3
from botocore.exceptions import NoCredentialsError
import json
import numpy as np
import pandas as pd
import glob
import torchvision

# %%
# !wget -c "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet152_a1h-dc400468.pth"
# !wget -c "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-effv2-weights/tf_efficientnetv2_s-eb54923e.pth" 
# !wget -c "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth"
# !wget -c "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet152_a1h-dc400468.pth"
# !wget -c "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-weights/efficientnet_b0_ra-3dd342df.pth"
# !wget -c "https://download.pytorch.org/models/efficientnet_b5_lukemelas-b6417697.pth" 
# !wget -c "https://download.pytorch.org/models/efficientnet_b2_rwightman-bcdf34b7.pth"
# !wget -c "https://download.pytorch.org/models/efficientnet_b0_rwightman-3dd342df.pth"
# !wget -c "https://download.pytorch.org/models/efficientnet_b7_lukemelas-dcc49843.pth"
# Out:
# --2024-02-15 03:07:21--  https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet152_a1h-dc400468.pth
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/huggingface/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet152_a1h-dc400468.pth [following]
# --2024-02-15 03:07:21--  https://github.com/huggingface/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet152_a1h-dc400468.pth
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !pip download nvidia-dali
# !pip download  "python-gdcm" pydicom pylibjpeg  torchvision dicomsdl
# !pip download timm
# Out:
# ...
# error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [19 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 36, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-download-k8a28tr5/nvidia-dali_4fe45b0779bb4d8ea806546ce80cf7a4/setup.py", line 150, in <module>
#           raise RuntimeError(open("ERROR.txt", "r").read())
#       RuntimeError:
#       ###########################################################################################
#       The package you are trying to install is only a placeholder project on PyPI.org repository.
#       This package is hosted on NVIDIA Python Package Index.
#
#       This package can be installed as:
#       ```
#       $ pip install nvidia-pyindex
#       $ pip install nvidia-dali
#       ```
#
#       Please refer to NVIDIA DALI installation guide for instructions:
# ...

# %%
# !ls /kaggle/working/
# Out:
# Pillow-9.5.0-cp37-cp37m-manylinux_2_28_x86_64.whl
# PyYAML-6.0.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# __notebook__.ipynb
# certifi-2024.2.2-py3-none-any.whl
# charset_normalizer-3.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# dicomsdl-0.109.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl
# efficientnet_b0_ra-3dd342df.pth
# efficientnet_b0_rwightman-3dd342df.pth
# efficientnet_b2_rwightman-bcdf34b7.pth
# efficientnet_b5_lukemelas-b6417697.pth
# efficientnet_b7_lukemelas-dcc49843.pth
# filelock-3.12.2-py3-none-any.whl
# fsspec-2023.1.0-py3-none-any.whl
# huggingface_hub-0.16.4-py3-none-any.whl
# idna-3.6-py3-none-any.whl
# importlib_metadata-6.7.0-py3-none-any.whl
# numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl
# nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl
# nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl
# nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl
# ...
